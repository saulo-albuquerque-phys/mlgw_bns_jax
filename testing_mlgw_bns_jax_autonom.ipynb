# %%
from jax_import_n_predict import load_predict
import jax
import jax.numpy as jnp

params = jnp.array([1.1, 300.0, 300.0, 0.1, 0.1])
freqs  = jnp.linspace(20., 2048., 2000)
total_mass  = jnp.array(2.8)
distance_mpc = jnp.array(100.0)
inclination = jnp.array(0.0)

predict = jax.jit(load_predict("mlgw_bns_jax_model.h5"))

# %%
hp, hc = predict(params, freqs, total_mass, distance_mpc, inclination)
